# %% [markdown]
# ## task 1 bikes.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

bikes_df=pd.read_csv('bikes.csv')
bikes_df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %% [markdown]
# ### Numerical Visualization

# %%
plt.plot(bikes_df['temp'],bikes_df['rented_bikes_count'],label='viz1')
plt.legend()
plt.xlabel('Temperature ..')
plt.ylabel('Rented bikes count ..')
plt.title('temp vs rented bikes count ')
# Out:
# Text(0.5, 1.0, 'temp vs rented bikes count ')

# %%
plt.plot(bikes_df['humidity'],bikes_df['rented_bikes_count'],label='viz1')
plt.legend()
plt.xlabel('humidity ..')
plt.ylabel('Rented bikes count ..')
plt.title('humidity vs rented bikes count ')
# Out:
# Text(0.5, 1.0, 'humidity vs rented bikes count ')

# %%
plt.hist(bikes_df['rented_bikes_count'])
# Out:
# (array([4284., 2337., 1686., 1067.,  633.,  426.,  233.,  116.,   85.,
#           19.]),
#  array([  1. ,  98.6, 196.2, 293.8, 391.4, 489. , 586.6, 684.2, 781.8,
#         879.4, 977. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(bikes_df['casual'],color='m',bins=30)#cmykrgb
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='casual', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.distplot(bikes_df['registered'],kde=False,bins=30,color='g')
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='registered'>

# %%
sns.kdeplot(bikes_df['temp'],color='m',shade=True)
# Out:
# <AxesSubplot:xlabel='temp', ylabel='Density'>

# %%
sns.jointplot(x='temp',y='rented_bikes_count',data=bikes_df,kind='kde')

# %%
sns.jointplot(x='humidity',y='rented_bikes_count',data=bikes_df,kind='hex')

# %%
sns.pairplot(bikes_df)

# %%
sns.pairplot(bikes_df,vars=['casual','registered'],height=4,aspect=1.4,hue='temp')
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Categorical Visualitsation

# %%
sns.boxplot(y='weather',x='rented_bikes_count',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='weather'>

# %%
sns.boxplot(y='season',x='rented_bikes_count',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='season'>

# %%
sns.violinplot(x='weather',y='casual',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='casual'>

# %%
sns.violinplot(x='season',y='casual',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='casual'>

# %%
sns.stripplot(x='weather',y='registered',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='registered'>

# %%
sns.stripplot(x='weather',y='registered',data=bikes_df,hue='season')
# Out:
# <AxesSubplot:xlabel='weather', ylabel='registered'>

# %%
sns.swarmplot(x='weather',y='rented_bikes_count',data=bikes_df,hue='season',dodge=True)
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.barplot(x='weather',y='rented_bikes_count',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='rented_bikes_count'>

# %%
sns.barplot(x='season',y='rented_bikes_count',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='rented_bikes_count'>

# %%
sns.heatmap(bikes_df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='weather',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
sns.countplot(x='season',data=bikes_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
sns.countplot(x='weather',data=bikes_df,hue='season')
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %% [markdown]
# ## task 2 loan_data.csv

# %%
loan_df=pd.read_csv('loan_data.csv')
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### 1- numerical analysis

# %%
plt.plot(loan_df['ApplicantIncome'],loan_df['LoanAmount'],label='viz1')
plt.legend()
plt.xlabel('Temperature ..')
plt.ylabel('Rented bikes count ..')
plt.title('temp vs rented bikes count ')
# Out:
# Text(0.5, 1.0, 'temp vs rented bikes count ')

# %%
plt.plot(loan_df['CoapplicantIncome'],loan_df['LoanAmount'],label='viz1')
plt.legend()
plt.xlabel('Temperature ..')
plt.ylabel('Rented bikes count ..')
plt.title('temp vs rented bikes count ')
# Out:
# Text(0.5, 1.0, 'temp vs rented bikes count ')

# %%
plt.hist(loan_df['LoanAmount'])
# Out:
# (array([ 72., 310., 143.,  33.,  15.,   6.,   5.,   3.,   3.,   2.]),
#  array([  9. ,  78.1, 147.2, 216.3, 285.4, 354.5, 423.6, 492.7, 561.8,
#         630.9, 700. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(loan_df['LoanAmount'],color='m',bins=30)#cmykrgb
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.distplot(loan_df['CoapplicantIncome'],kde=False,bins=30,color='g')
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CoapplicantIncome'>

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.distplot(loan_df['ApplicantIncome'],kde=False,bins=30,color='g')
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
sns.kdeplot(loan_df['LoanAmount'],color='m',shade=True)
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount',data=loan_df,kind='kde')

# %%
sns.jointplot(x='CoapplicantIncome',y='LoanAmount',data=loan_df,kind='hex')

# %%
sns.pairplot(loan_df)

# %% [markdown]
# ### Categorical Visualization

# %%
sns.boxplot(y='Gender',x='ApplicantIncome',data=loan_df)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Gender'>

# %%
sns.boxplot(y='Married',x='CoapplicantIncome',data=loan_df)
# Out:
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Married'>

# %%
sns.boxplot(y='Dependents',x='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Dependents'>

# %%
sns.violinplot(x='Married',y='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
sns.violinplot(x='Gender',y='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.stripplot(x='Education',y='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.stripplot(x='Property_Area',y='LoanAmount',data=loan_df,hue='Married')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.swarmplot(x='Property_Area',y='LoanAmount',data=loan_df,hue='Married',dodge=True)
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.barplot(x='Education',y='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.barplot(x='Gender',y='LoanAmount',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.heatmap(loan_df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Gender',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Married',data=loan_df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
sns.countplot(x='Gender',data=loan_df,hue='Married')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>
