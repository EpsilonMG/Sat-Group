# %% [markdown]
# # Bikes

# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('bikes.csv')
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.describe()
# Out:
#             holiday   workingday         temp     humidity    windspeed  \
# count  10030.000000  9388.000000  8104.000000  7462.000000  6820.000000
# mean       0.029113     0.678206    20.317665    61.790673    12.708806
# std        0.168131     0.467189     7.818568    19.262084     8.131154
# min        0.000000     0.000000     0.820000     0.000000     0.000000
# 25%        0.000000     0.000000    13.940000    47.000000     7.001500
# 50%        0.000000     1.000000    20.500000    62.000000    12.998000
# 75%        0.000000     1.000000    26.240000    77.000000    16.997900
# max        1.000000     1.000000    41.000000   100.000000    56.996900
#
#              casual    registered  rented_bikes_count
# count  10886.000000  10886.000000        10886.000000
# mean      36.021955    155.552177          191.574132
# std       49.960477    151.039033          181.144454
# min        0.000000      0.000000            1.000000
# ...

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.distplot(df['rented_bikes_count'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='Density'>

# %%
sns.jointplot(x='casual',y='rented_bikes_count',data=df,hue='workingday')

# %%
sns.jointplot(x='casual',y='rented_bikes_count',data=df,hue='holiday')

# %%
sns.jointplot(x='registered',y='rented_bikes_count',data=df,hue='workingday')

# %%
sns.jointplot(x='registered',y='rented_bikes_count',data=df,hue='holiday')

# %%
df['profit']=(df['registered']*5+df['casual']*20)-0.14*(df['registered']*5+df['casual']*20)-(1500/(365*24))
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %% [markdown]
# ## Numerical

# %%
sns.distplot(df['profit'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='profit', ylabel='Density'>

# %%
sns.distplot(df['registered'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='registered', ylabel='Density'>

# %%
sns.distplot(df['casual'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='casual', ylabel='Density'>

# %%
sns.distplot(df['windspeed'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='windspeed', ylabel='Density'>

# %%
sns.distplot(df['humidity'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
sns.distplot(df['temp'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temp', ylabel='Density'>

# %%
sns.jointplot(x='temp', y='profit', data=df, color='m')

# %%
sns.jointplot(x='temp', y='profit', data=df, color='m',hue='season')

# %%
sns.jointplot(x='humidity', y='profit', data=df, color='m')

# %%
sns.jointplot(x='windspeed', y='profit', data=df, color='m')

# %%
sns.jointplot(x='casual', y='profit', data=df, color='m')

# %%
sns.jointplot(x='registered', y='profit', data=df, color='m')

# %% [markdown]
# ## Categorical

# %%
sns.countplot('weather',data=df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
sns.countplot('workingday',data=df)
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %%
sns.countplot('holiday',data=df)
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='holiday', ylabel='count'>

# %%
sns.countplot('season',data=df)
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
sns.boxplot(x='season', y='profit', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='season', ylabel='profit'>

# %%
sns.boxplot(x='weather', y='profit', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='weather', ylabel='profit'>

# %%
sns.boxplot(x='holiday', y='profit', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='holiday', ylabel='profit'>

# %%
sns.boxplot(x='workingday', y='profit', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='profit'>

# %%
sns.violinplot(x='season',y='rented_bikes_count',hue='weather',data=df ,palette='viridis')
# Out:
# <AxesSubplot:xlabel='season', ylabel='rented_bikes_count'>

# %%
sns.heatmap(df.corr(),annot=True,linecolor='w',linewidths=3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # loan

# %%
df=pd.read_csv('loan_data.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Numerical:
# 1. CoapplicantIncome
# 2. LoanAmount
# 3. Loan_Amount_Term
# 4. Application Income

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.jointplot(x='LoanAmount',y='ApplicantIncome',data=df)

# %%
sns.jointplot(x='LoanAmount',y='Loan_Amount_Term',data=df)

# %%
sns.jointplot(x='CoapplicantIncome',y='ApplicantIncome',data=df)

# %% [markdown]
# ## Categorical
# 1. Gender
# 2. Married
# 3. Dependents
# 4. Education
# 5. Self_Employed
# 6. Credit_History
# 7. Property_Area
# 8. Loan_Status

# %%
sns.countplot('Gender',data=df, palette='Set1')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot('Married',data=df, palette='Set2')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
sns.countplot('Dependents',data=df, palette='Set3')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot('Education',data=df, palette='Set1')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot('Self_Employed',data=df, palette='Set2')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot('Credit_History',data=df, palette='Set3')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %%
sns.countplot('Property_Area',data=df, palette='Set1')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
sns.countplot('Loan_Status',data=df, palette='Set2')
# Out:
# C:\Users\mega\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.jointplot(x='LoanAmount',y='ApplicantIncome',data=df,hue='Loan_Status')

# %%
sns.boxplot(x='Gender', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Married', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Dependents', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Education', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Self_Employed', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Credit_History', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Property_Area', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.boxplot(x='Loan_Status', y='LoanAmount', data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>
