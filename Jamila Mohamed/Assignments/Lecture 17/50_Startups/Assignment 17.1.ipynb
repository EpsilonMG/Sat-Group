# %% [markdown]
# ### 50_Startups

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Regression/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='State',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.jointplot(x=df['State'],y=df['Profit'])

# %%
sns.jointplot(x=df['R&D Spend'],y=df['Profit'])

# %%
sns.jointplot(x=df['Marketing Spend'],y=df['Profit'])

# %%
df=pd.get_dummies(df,columns=['State'],drop_first=True)
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
from datasist.structdata import detect_outliers
indices=detect_outliers(df,0,['R&D Spend','Administration','Marketing Spend','Profit'])
indices
# Out:
# [49]

# %%
df.drop(indices,inplace=True)
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
x=df.drop('Profit',axis=1)
y=df['Profit']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[ 1.95199989e+00, -6.49772280e-01,  1.66174221e+00,
#          1.50000000e+00, -7.48331477e-01],
#        [-1.62909531e+00,  1.47437906e-01, -1.76538621e+00,
#         -6.66666667e-01,  1.33630621e+00],
#        [-5.61967968e-01,  1.30963036e+00, -2.20467817e-03,
#         -6.66666667e-01, -7.48331477e-01],
#        [ 1.38735644e-01, -2.08963279e-01,  7.39440902e-01,
#         -6.66666667e-01, -7.48331477e-01],
#        [ 5.52420787e-01,  2.57186328e-01,  3.27329983e-01,
#          1.50000000e+00, -7.48331477e-01],
#        [ 7.41512724e-01, -3.22379406e-01,  1.52791810e-01,
#          1.50000000e+00, -7.48331477e-01],
#        [-1.28833737e+00,  2.59331857e-01, -1.48152793e+00,
#         -6.66666667e-01,  1.33630621e+00],
#        [-1.62169004e+00, -1.41433492e-01,  7.26357940e-01,
#          1.50000000e+00, -7.48331477e-01],
#        [-1.11412232e-01,  1.14809677e+00, -8.77147823e-01,
#         -6.66666667e-01,  1.33630621e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models={
    'LR':LinearRegression(),
    'KNR':KNeighborsRegressor(n_neighbors=5),
    'SVR':SVR(),
    'DTR':DecisionTreeRegressor(),
    'RFR':RandomForestRegressor(n_estimators=20),
    'XGBR':XGBRegressor(n_estimators=60,learning_rate=0.1,booster='gblinear')
}

# %%
for name,model in models.items():
    print(f'using: {name}')
    model.fit(x_train,y_train)
    print(f'training accuracy: {model.score(x_train,y_train)}')
    print(f'testing accuracy: {model.score(x_test,y_test)}')
    print('_'*30)
# Out:
# using: LR
# training accuracy: 0.9556842706125841
# testing accuracy: 0.9724024782687106
# ______________________________
# using: KNR
# training accuracy: 0.6992046582149154
# testing accuracy: 0.7238302858202494
# ______________________________
# using: SVR
# training accuracy: -0.0018267664039726128
# testing accuracy: -0.2837234882924582
# ______________________________
# using: DTR
# training accuracy: 1.0
# testing accuracy: 0.8514522858890553
# ______________________________
# using: RFR
# training accuracy: 0.9872662712334082
# testing accuracy: 0.9185758200239652
# ______________________________
# using: XGBR
# training accuracy: 0.9509601236380613
# testing accuracy: 0.9837318632501904
# ______________________________

# %%
model=XGBRegressor(n_estimators=60,learning_rate=0.1,booster='gblinear')
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9724024782687106

# %%
x.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida',
#        'State_New York'],
#       dtype='object')

# %%
data=[200000,150000,350000]+[0,1]

# %%
data=scaler.transform([data])
data
# Out:
# array([[ 3.04573504,  1.04303581,  1.17274186, -0.66666667,  1.33630621]])

# %%
pred=model.predict(data)
pred
# Out:
# array([216817.87225024])

# %%
import joblib

# %%
joblib.dump(model,'model1.h5')
joblib.dump(scaler,'scaler1.h5')
joblib.dump(x.columns,'features1.h5')
# Out:
# ['features1.h5']

# %%
model=joblib.load('model1.h5')

# %%
model.intercept_
# Out:
# 110186.76384615384

# %%
model.coef_
# Out:
# array([34931.84570847, -1282.18505025,  1938.98396283,  -916.56313592,
#         -980.04690878])

# %%
features=joblib.load('features1.h5')
features
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida',
#        'State_New York'],
#       dtype='object')
