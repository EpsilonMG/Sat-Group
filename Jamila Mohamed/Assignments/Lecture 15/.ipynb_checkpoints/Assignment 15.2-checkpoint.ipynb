# %% [markdown]
# ### LOAN DATA

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)

# %%
df=pd.read_csv('datasets/loan_data.csv')
df
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df['purpose'].describe()
# Out:
# count                   9578
# unique                     7
# top       debt_consolidation
# freq                    3957
# Name: purpose, dtype: object

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %%
df['purpose'].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %%
sns.set(rc={'figure.figsize': [15, 10]}, font_scale=1.3)

# %%
sns.countplot(x=df['purpose'],data=df)
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
df['credit.policy'].value_counts()
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %%
df['credit.policy'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.countplot(x=df['purpose'],hue=df['credit.policy'])
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
df['not.fully.paid'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.countplot(x=df['purpose'],hue=df['not.fully.paid'])
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
df['inq.last.6mths'].value_counts()
# Out:
# 0     3637
# 1     2462
# 2     1384
# 3      864
# 4      475
# 5      278
# 6      165
# 7      100
# 8       72
# 9       47
# 10      23
# 12      15
# 11      15
# 15       9
# 13       6
# 14       6
# 18       4
# 16       3
# 19       2
# 17       2
# 24       2
# 33       1
# 27       1
# 25       1
# 20       1
# 28       1
# 32       1
# 31       1
# Name: inq.last.6mths, dtype: int64

# %%
df['inq.last.6mths'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5,  6,  8,  7, 33,  9, 18, 14, 15, 13, 12, 10,
#        19, 11, 16, 20, 27, 25, 28, 31, 24, 17, 32], dtype=int64)

# %%
sns.set(rc={'figure.figsize': [15, 15]}, font_scale=1.3)

# %%
sns.countplot(x=df['purpose'],hue=df['inq.last.6mths'])
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)

# %%
sns.catplot(x='credit.policy',y='inq.last.6mths',data=df,kind='strip')

# %%
sns.set(rc={'figure.figsize': [15, 10]}, font_scale=1.3)

# %%
sns.violinplot(x='purpose',y='installment',data=df,hue='credit.policy')
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='installment'>

# %%
df.corr()
# Out:
#                    credit.policy  int.rate  installment  log.annual.inc  \
# credit.policy           1.000000 -0.294089     0.058770        0.034906
# int.rate               -0.294089  1.000000     0.276140        0.056383
# installment             0.058770  0.276140     1.000000        0.448102
# log.annual.inc          0.034906  0.056383     0.448102        1.000000
# dti                    -0.090901  0.220006     0.050202       -0.054065
# fico                    0.348319 -0.714821     0.086039        0.114576
# days.with.cr.line       0.099026 -0.124022     0.183297        0.336896
# revol.bal              -0.187518  0.092527     0.233625        0.372140
# revol.util             -0.104095  0.464837     0.081356        0.054881
# inq.last.6mths         -0.535511  0.202780    -0.010419        0.029171
# delinq.2yrs            -0.076318  0.156079    -0.004368        0.029203
# pub.rec                -0.054243  0.098162    -0.032760        0.016506
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),linecolor='white',linewidths=2)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),linecolor='white',linewidths=2,annot=True)
# Out:
# <AxesSubplot:>

# %%
df=pd.get_dummies(df,columns=['purpose'],drop_first=True)
df
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
x=df.drop('not.fully.paid',axis=1)
y=df['not.fully.paid']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 201               1    0.1154       527.93       10.700995  12.16   682
# 1595              1    0.1083       146.97       11.002100   8.66   712
# 1571              1    0.1146       494.36       11.225243  11.58   707
# 8356              0    0.1545       191.88       11.512925  22.46   647
# 8461              0    0.1229       667.06       11.264464   2.38   692
# ...             ...       ...          ...             ...    ...   ...
# 9388              0    0.1287       336.34       10.933107  16.22   712
# 2150              1    0.1284       228.61       10.878047  11.59   707
# 2153              1    0.0963       192.57       10.348173  22.46   732
# 4937              1    0.1392       682.74       11.350359  12.61   707
# 9150              0    0.1284       168.09       10.308953  13.80   687
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
x_test
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 7145              1    0.1348       237.47       10.819778  11.09   677
# 5169              1    0.1114       352.64       10.239960  21.00   727
# 8665              0    0.1355       203.76       11.482425  12.15   657
# 1320              1    0.0800       184.89       12.345835   3.92   782
# 1280              1    0.1633       264.91       10.819778  10.80   667
# ...             ...       ...          ...             ...    ...   ...
# 1957              1    0.1221       119.94       11.002100  10.56   692
# 9424              0    0.1253       167.34       11.877569   8.50   702
# 9449              0    0.1600       351.58       11.018629   8.79   702
# 6664              1    0.1273       342.38       10.915088   9.60   697
# 561               1    0.1292       213.72       11.294956  20.15   677
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
y_train
# Out:
# 201     1
# 1595    0
# 1571    0
# 8356    0
# 8461    0
#        ..
# 9388    0
# 2150    0
# 2153    0
# 4937    0
# 9150    1
# Name: not.fully.paid, Length: 7183, dtype: int64

# %%
y_test
# Out:
# 7145    0
# 5169    0
# 8665    1
# 1320    0
# 1280    1
#        ..
# 1957    0
# 9424    0
# 9449    0
# 6664    0
# 561     0
# Name: not.fully.paid, Length: 2395, dtype: int64

# %%
y_train.value_counts()*100/len(y_train)
# Out:
# 0    84.25449
# 1    15.74551
# Name: not.fully.paid, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
sampler=SMOTE()
x_train,y_train=sampler.fit_resample(x_train,y_train)
y_train.value_counts()
# Out:
# 0    6052
# 1    6052
# Name: not.fully.paid, dtype: int64
