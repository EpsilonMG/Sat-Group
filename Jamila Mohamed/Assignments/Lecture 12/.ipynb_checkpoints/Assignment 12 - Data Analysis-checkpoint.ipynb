# %% [markdown]
# ### bikes.csv

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Assignment datasets/bikes.csv')
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.describe()
# Out:
#             holiday   workingday         temp     humidity    windspeed  \
# count  10030.000000  9388.000000  8104.000000  7462.000000  6820.000000
# mean       0.029113     0.678206    20.317665    61.790673    12.708806
# std        0.168131     0.467189     7.818568    19.262084     8.131154
# min        0.000000     0.000000     0.820000     0.000000     0.000000
# 25%        0.000000     0.000000    13.940000    47.000000     7.001500
# 50%        0.000000     1.000000    20.500000    62.000000    12.998000
# 75%        0.000000     1.000000    26.240000    77.000000    16.997900
# max        1.000000     1.000000    41.000000   100.000000    56.996900
#
#              casual    registered  rented_bikes_count
# count  10886.000000  10886.000000        10886.000000
# mean      36.021955    155.552177          191.574132
# std       49.960477    151.039033          181.144454
# min        0.000000      0.000000            1.000000
# ...

# %%
#Make Profit Feature

# %%
def ext_profit(x):
    profit=(x['registered']*5)+(x['casual']*20)
    taxes=profit*0.14
    maint=1500/(365*24)
    profit=profit-(taxes+maint)
    return profit

df['Profit']=df.apply(ext_profit,axis=1)
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
#Distribution rental_bikes_count & profit

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.jointplot(x="rented_bikes_count",y="Profit",data=df)

# %%
#Profit for each day

# %%
df['Day']=df['datetime'].apply( lambda x : x.split()[0])
df.groupby('Day').sum()['Profit']
# Out:
# Day
# 2011-01-01     8501.290411
# 2011-01-02     5130.261644
# 2011-01-03     7344.932877
# 2011-01-04     8105.861644
# 2011-01-05     7933.861644
#                   ...
# 2012-12-15    31592.290411
# 2012-12-16    23215.890411
# 2012-12-17    22446.190411
# 2012-12-18    29476.690411
# 2012-12-19    26939.690411
# Name: Profit, Length: 456, dtype: float64

# %%
#Which season that has more registeration?

# %%
df.groupby('season').sum()['registered']
# Out:
# season
# Fall      488252
# Spring    265322
# Summer    446991
# Winter    457276
# Name: registered, dtype: int64

# %%
#Which season that has more profit?

# %%
df.groupby('season').sum()['Profit']
# Out:
# season
# Fall      4.509295e+06
# Spring    1.836294e+06
# Summer    4.093775e+06
# Winter    3.286013e+06
# Name: Profit, dtype: float64

# %%
#Which weather condition that has more registeration?

# %%
df.groupby('weather').sum()['registered']
# Out:
# weather
# Clear    951449
# Mist     336229
# Rainy     70204
# Snowy       158
# Name: registered, dtype: int64

# %%
#Which weather condition that has more profit?

# %%
df.groupby('weather').sum()['Profit']
# Out:
# weather
# Clear    8.062699e+06
# Mist     2.645321e+06
# Rainy    5.096033e+05
# Snowy    7.824288e+02
# Name: Profit, dtype: float64

# %%
#Correlation between profit & bikes count with all features

# %%
df.corr()[['Profit','rented_bikes_count']]
# Out:
#                       Profit  rented_bikes_count
# holiday             0.017410           -0.005827
# workingday         -0.150218            0.010940
# temp                0.462618            0.391867
# humidity           -0.358150           -0.317282
# windspeed           0.100205            0.097747
# casual              0.902713            0.690414
# registered          0.822156            0.970948
# rented_bikes_count  0.934490            1.000000
# Profit              1.000000            0.934490

# %%
df['datetime']=pd.to_datetime(df['datetime'],format='%Y/%m/%d %H:%M:%S')
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df['rented_bikes_hour']=df['datetime'].dt.hour
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
#Rentals during rush hours (7-9 am)

# %%
df[df['rented_bikes_hour'].between(7,9)]
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 7     2011-01-01 07:00:00  Spring      0.0         0.0   Clear   8.20
# 8     2011-01-01 08:00:00  Spring      0.0         0.0     NaN   9.84
# 9     2011-01-01 09:00:00  Spring      0.0         0.0   Clear    NaN
# 30    2011-01-02 07:00:00  Spring      0.0         0.0     NaN  16.40
# 31    2011-01-02 08:00:00  Spring      0.0         0.0   Rainy  16.40
# ...                   ...     ...      ...         ...     ...    ...
# 10846 2012-12-18 08:00:00  Winter      0.0         NaN   Clear  15.58
# 10847 2012-12-18 09:00:00  Winter      0.0         1.0   Clear    NaN
# 10869 2012-12-19 07:00:00  Winter      0.0         1.0   Clear    NaN
# 10870 2012-12-19 08:00:00  Winter      0.0         1.0   Clear    NaN
# 10871 2012-12-19 09:00:00  Winter      0.0         1.0   Clear    NaN
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
#Rentals during rush hours (3-5 pm)

# %%
df[df['rented_bikes_hour'].between(15,17)]
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 15    2011-01-01 15:00:00  Spring      0.0         0.0    Mist  18.04
# 16    2011-01-01 16:00:00  Spring      0.0         0.0    Mist  17.22
# 17    2011-01-01 17:00:00  Spring      NaN         NaN    Mist  18.04
# 38    2011-01-02 15:00:00  Spring      0.0         0.0   Rainy  13.94
# 39    2011-01-02 16:00:00  Spring      0.0         0.0   Rainy  13.94
# ...                   ...     ...      ...         ...     ...    ...
# 10854 2012-12-18 16:00:00  Winter      0.0         1.0     NaN    NaN
# 10855 2012-12-18 17:00:00  Winter      0.0         1.0   Clear  16.40
# 10877 2012-12-19 15:00:00  Winter      NaN         1.0   Clear    NaN
# 10878 2012-12-19 16:00:00  Winter      0.0         1.0   Clear    NaN
# 10879 2012-12-19 17:00:00  Winter      0.0         NaN   Clear    NaN
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
#Rentals during holiday

# %%
df[df['holiday']>0]['rented_bikes_count'].sum()
# Out:
# 54128

# %%
#Rentals during workday

df[df['workingday']>0]['rented_bikes_count'].sum()
# Out:
# 1226368

# %%
#Registered or casual is more

# %%
df['registered'].sum()
# Out:
# 1693341

# %%
df['casual'].sum()
# Out:
# 392135

# %%
#What is the average of bikes would be registered during the week?

# %%
df['Week']=df['datetime'].dt.week
df
# Out:
# <ipython-input-34-993b5eeb4fe4>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['Week']=df['datetime'].dt.week
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# ...

# %%
df.groupby('Week').mean()['registered']
# Out:
# Week
# 1      85.310030
# 2      82.381818
# 3      93.811688
# 5      95.072797
# 6      94.621212
# 7     108.958065
# 9      93.192469
# 10    112.318182
# 11    142.649351
# 12    215.458333
# 13     89.229167
# 14    135.964179
# 15    141.637725
# 16    181.722222
# 17     92.208333
# 18    171.253205
# 19    175.181548
# 20    184.820833
# 22    171.182292
# 23    193.092262
# 24    190.803571
# 25    214.645833
# 26    140.708333
# 27    167.973214
# 28    190.752976
# 29    205.763889
# 31    175.121528
# 32    182.452381
# 33    194.121528
# 35    139.840278
# 36    170.047904
# 37    207.447761
# 38    210.416667
# 39     88.562500
# 40    190.029762
# 41    183.711310
# 42    206.905759
# 44    162.237500
# 45    168.797015
# 46    162.028846
# 47    210.416667
# 48    145.645833
# 49    155.738095
# 50    162.455357
# 51    183.062500
# 52     41.295775
# Name: registered, dtype: float64

# %%
#Schools (9-12) & (2-6) profit

# %%
df['Month']=df['datetime'].dt.month
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[df['Month'].between(9,12)]
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 3602  2011-09-01 00:00:00    Fall      0.0         1.0   Clear  24.60
# 3603  2011-09-01 01:00:00    Fall      0.0         1.0   Clear  24.60
# 3604  2011-09-01 02:00:00    Fall      0.0         1.0     NaN  23.78
# 3605  2011-09-01 03:00:00    Fall      0.0         1.0     NaN  23.78
# 3606  2011-09-01 04:00:00    Fall      0.0         1.0   Clear  22.96
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[df['Month'].between(9,12)]['Profit']
# Out:
# 3602      451.328767
# 3603      180.428767
# 3604      287.928767
# 3605      150.328767
# 3606       29.928767
#             ...
# 10881    1534.928767
# 10882    1165.128767
# 10883     773.828767
# 10884     709.328767
# 10885     429.828767
# Name: Profit, Length: 3643, dtype: float64

# %%
df[df['Month'].between(2,6)]
# Out:
#                 datetime  season  holiday  workingday weather   temp  \
# 431  2011-02-01 00:00:00  Spring      0.0         1.0     NaN   6.56
# 432  2011-02-01 01:00:00  Spring      0.0         1.0    Mist   6.56
# 433  2011-02-01 02:00:00  Spring      0.0         NaN    Mist   6.56
# 434  2011-02-01 03:00:00  Spring      0.0         1.0    Mist   6.56
# 435  2011-02-01 05:00:00  Spring      NaN         1.0     NaN   5.74
# ...                  ...     ...      ...         ...     ...    ...
# 8146 2012-06-19 19:00:00  Summer      0.0         NaN   Clear  32.80
# 8147 2012-06-19 20:00:00  Summer      0.0         1.0   Clear  32.80
# 8148 2012-06-19 21:00:00  Summer      NaN         1.0   Clear  31.16
# 8149 2012-06-19 22:00:00     NaN      0.0         1.0   Clear    NaN
# 8150 2012-06-19 23:00:00  Summer      0.0         1.0   Clear  29.52
#
#       humidity  windspeed  casual  registered  rented_bikes_count  \
# 431        NaN        NaN       2           6                   8
# ...

# %%
df[df['Month'].between(2,6)]['Profit']
# Out:
# 431       60.028767
# 432       12.728767
# 433        8.428767
# 434        8.428767
# 435       12.728767
#            ...
# 8146    3267.828767
# 8147    2730.328767
# 8148    1663.928767
# 8149    1909.028767
# 8150     834.028767
# Name: Profit, Length: 4535, dtype: float64

# %%
df[df['Month'].between(2,6) | df['Month'].between(9,12)]
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 431   2011-02-01 00:00:00  Spring      0.0         1.0     NaN   6.56
# 432   2011-02-01 01:00:00  Spring      0.0         1.0    Mist   6.56
# 433   2011-02-01 02:00:00  Spring      0.0         NaN    Mist   6.56
# 434   2011-02-01 03:00:00  Spring      0.0         1.0    Mist   6.56
# 435   2011-02-01 05:00:00  Spring      NaN         1.0     NaN   5.74
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[df['Month'].between(2,6) | df['Month'].between(9,12)]['Profit']
# Out:
# 431        60.028767
# 432        12.728767
# 433         8.428767
# 434         8.428767
# 435        12.728767
#             ...
# 10881    1534.928767
# 10882    1165.128767
# 10883     773.828767
# 10884     709.328767
# 10885     429.828767
# Name: Profit, Length: 8178, dtype: float64

# %%
df[df['Month'].between(2,6) | df['Month'].between(9,12)]['Profit'].sum()
# Out:
# 10497724.757534247

# %%
#Profit in 2011 & saturdays & season fall

# %%
df['Year']=df['datetime'].dt.year
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df['DayName']=df['datetime'].dt.day_name()
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[(df['Year']==2011) & (df['DayName']=='Saturday') & (df['season']=='Fall')]
# Out:
#                 datetime season  holiday  workingday weather   temp  humidity  \
# 2714 2011-07-02 00:00:00   Fall      0.0         0.0   Clear  27.88       NaN
# 2715 2011-07-02 01:00:00   Fall      0.0         0.0   Clear  27.06      54.0
# 2716 2011-07-02 02:00:00   Fall      0.0         0.0   Clear  26.24      53.0
# 2717 2011-07-02 03:00:00   Fall      0.0         0.0     NaN  26.24       NaN
# 2718 2011-07-02 04:00:00   Fall      0.0         0.0   Clear  25.42       NaN
# ...                  ...    ...      ...         ...     ...    ...       ...
# 4002 2011-09-17 19:00:00   Fall      0.0         0.0   Clear  21.32       NaN
# 4003 2011-09-17 20:00:00   Fall      0.0         0.0   Clear  21.32       NaN
# 4004 2011-09-17 21:00:00   Fall      0.0         0.0    Mist    NaN       NaN
# 4005 2011-09-17 22:00:00   Fall      0.0         0.0   Clear  20.50       NaN
# 4006 2011-09-17 23:00:00   Fall      0.0         0.0   Clear  18.86       NaN
#
# ...

# %%
df[(df['Year']==2011) & (df['DayName']=='Saturday') & (df['season']=='Fall')]['Profit']
# Out:
# 2714     894.228767
# 2715     593.228767
# 2716     339.528767
# 2717     176.128767
# 2718      85.828767
#            ...
# 4002    2003.628767
# 4003    1311.328767
# 4004    1362.928767
# 4005    1014.628767
# 4006    1049.028767
# Name: Profit, Length: 187, dtype: float64

# %%
df[(df['Year']==2011) & (df['DayName']=='Saturday') & (df['season']=='Fall')]['Profit'].sum()
# Out:
# 351695.0794520548

# %% [markdown]
# ### loan_data.csv

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Assignment datasets/loan_data.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Which Gender has more income?

# %%
#Males get more income than females

df.groupby('Gender').sum()['ApplicantIncome']
# Out:
# Gender
# Female     520069
# Male      2663319
# Name: ApplicantIncome, dtype: int64

# %%
#Which Gender has asked for more LoanAmount?

# %%
#Males ask for more LoanAmount

df.groupby('Gender').sum()['LoanAmount']
# Out:
# Gender
# Female    13810.0
# Male      70155.0
# Name: LoanAmount, dtype: float64

# %%
#Which Gender has Credit_History?

# %%
#Males have more Credit_History than females

df.groupby('Gender').sum()['Credit_History']
# Out:
# Gender
# Female     84.0
# Male      382.0
# Name: Credit_History, dtype: float64

# %%
#ApplicantIncome, LoanAmount, and Credit_History of Married
#Married people has more ApplicantIncome, asks for more LoanAmount, and has more Credit_History

# %%
df.groupby('Married').sum()[['ApplicantIncome','LoanAmount','Credit_History']]
# Out:
#          ApplicantIncome  LoanAmount  Credit_History
# Married
# No               1058692     26550.0           167.0
# Yes              2240411     59808.0           305.0

# %%
#Correlation between LoanAmount & ApplicantIncome with all features

# %%
df.corr()[['LoanAmount','ApplicantIncome']]
# Out:
#                    LoanAmount  ApplicantIncome
# ApplicantIncome      0.570909         1.000000
# CoapplicantIncome    0.188619        -0.116605
# LoanAmount           1.000000         0.570909
# Loan_Amount_Term     0.039447        -0.045306
# Credit_History      -0.008433        -0.014715

# %%
#LoanAmount greater than 200 and Self_Employed

# %%
df[(df['LoanAmount']>200) & (df['Self_Employed']=='Yes')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 130  LP001469    Male      No          0      Graduate           Yes
# 212  LP001713    Male     Yes          1      Graduate           Yes
# 325  LP002067    Male     Yes          1      Graduate           Yes
# 372  LP002201    Male     Yes          2      Graduate           Yes
# 417  LP002342    Male     Yes          2      Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 523  LP002693    Male     Yes          2      Graduate           Yes
# 525  LP002699    Male     Yes          2      Graduate           Yes
# 557  LP002795    Male     Yes         3+      Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 591  LP002931    Male     Yes          2      Graduate           Yes
# ...

# %%
#Loan_Status is accepted and Self_Employed

# %%
df[(df['Loan_Status']=='Y') & (df['Self_Employed']=='Yes')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 71   LP001245    Male     Yes          2  Not Graduate           Yes
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 81   LP001266    Male     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 130  LP001469    Male      No          0      Graduate           Yes
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 137  LP001491    Male     Yes          2      Graduate           Yes
# ...

# %%
#Relationship between graduates and Self_Employed

# %%
df[(df['Education']=='Graduate') & (df['Self_Employed']=='Yes')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 25   LP001066    Male     Yes          0  Graduate           Yes
# 32   LP001097    Male      No          1  Graduate           Yes
# 54   LP001186  Female     Yes          1  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 591  LP002931    Male     Yes          2  Graduate           Yes
# 592  LP002933     NaN      No         3+  Graduate           Yes
# 594  LP002938    Male     Yes          0  Graduate           Yes
# 598  LP002945    Male     Yes          0  Graduate           Yes
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2               3000                0.0        66.0             360.0
# ...

# %%
#Relationship between not graduates and Self_Employed

# %%
df[(df['Education']=='Not Graduate') & (df['Self_Employed']=='Yes')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 62   LP001207    Male     Yes          0  Not Graduate           Yes
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 71   LP001245    Male     Yes          2  Not Graduate           Yes
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 174  LP001603    Male     Yes          0  Not Graduate           Yes
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 252  LP001841    Male      No          0  Not Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# ...
