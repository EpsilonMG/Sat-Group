# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('bikes.csv')

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
x= ((df['registered']*5)+(df['casual']*20))
df['Profit']=x-((0.14*100/x)+(1500/8760))

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df['rented_bikes_count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: rented_bikes_count, dtype: float64

# %%
df['Profit'].describe()
# Out:
# count    10886.000000
# mean      1497.926805
# std       1522.978811
# min          2.028767
# 25%        294.781309
# 50%       1034.815241
# 75%       2199.822403
# max       9164.827240
# Name: Profit, dtype: float64

# %%
df['datetime']=pd.to_datetime(df['datetime'])

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df['day']=df['datetime'].dt.day_name()

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df.groupby('day').sum()['Profit']
# Out:
# day
# Friday       2.223149e+06
# Monday       2.170375e+06
# Saturday     3.068935e+06
# Sunday       2.778597e+06
# Thursday     2.090803e+06
# Tuesday      1.989953e+06
# Wednesday    1.984619e+06
# Name: Profit, dtype: float64

# %%
df.groupby('season').sum()['Profit'].head(1)
# Out:
# season
# Fall    5.243301e+06
# Name: Profit, dtype: float64

# %%
df.groupby('season').sum()['registered'].head(1)
# Out:
# season
# Fall    488252
# Name: registered, dtype: int64

# %%
df.groupby('weather').sum().head(1)
# Out:
#          holiday  workingday      temp  humidity   windspeed  casual  \
# weather
# Clear      161.0      3340.0  89266.02  225598.0  46661.1383  230957
#
#          registered  rented_bikes_count        Profit
# weather
# Clear        951449             1182406  9.374832e+06

# %%
df[['rented_bikes_count','Profit']].corr()
# Out:
#                     rented_bikes_count    Profit
# rented_bikes_count            1.000000  0.934498
# Profit                        0.934498  1.000000

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[df['holiday']==1]['rented_bikes_count'].sum()
# Out:
# 54128

# %%
df[df['workingday']==1]['rented_bikes_count'].sum()
# Out:
# 1226368

# %%
df['Hour']=df['datetime'].dt.hour

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df[(df['Hour']>=7) & (df['Hour']<=9)]['rented_bikes_count'].sum()
# Out:
# 362938

# %%
df[(df['Hour']>=15) & (df['Hour']<=17)]['rented_bikes_count'].sum()
# Out:
# 473983

# %%
df[['registered','casual']].sum()
# Out:
# registered    1693341
# casual         392135
# dtype: int64

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df.drop('week',axis=1,inplace=True)

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
import datetime

# %%
df['week']=df['datetime'].dt.week
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df['day_num']=df['datetime'].dt.day

# %%
df.groupby('week').sum()
# Out:
#       holiday  workingday     temp  humidity  windspeed  casual  registered  \
# week
# 1        22.0       186.0  2316.50   11137.0  3173.0932    3212       28067
# 2         0.0       193.0  2281.24   13771.0  3009.1107    2105       27186
# 3        46.0        87.0  1152.92    5693.0  1852.0341     787       14447
# 5         0.0       144.0  2181.20   12287.0  1878.0569    2228       24814
# 6         0.0       198.0  2361.60   11452.0  2626.0717    2287       31225
# 7         0.0       210.0  3545.68    9357.0  3260.0257    4782       33777
# 9         0.0       122.0  2444.42    9152.0  2187.0073    3696       22273
# 10        0.0       210.0  3339.86   11321.0  3682.0654    7165       37065
# 11        0.0       205.0  4279.58   12776.0  2247.0929   13213       43936
# 12        0.0        21.0   472.32    1297.0   181.0005     982        5171
# 13        0.0        19.0   991.38    4250.0   854.0088    5203        8566
# ...

# %%
df.groupby('week').sum()['Profit'].mean()
# Out:
# 354487.6347693498

# %%
df[(df['Hour']>=9) & (df['Hour']<=12)]['Profit'].sum()
# Out:
# 3373372.8156669755

# %%
df[(df['Hour']>=14) & (df['Hour']<=18)]['Profit'].sum()
# Out:
# 6400363.418645995

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
df['year']=df['datetime'].dt.year

# %%
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
int(df[df['year']==2011]['Profit'].sum())
# Out:
# 6245561

# %%
int(df[df['day']=='Saturday']['Profit'].sum())
# Out:
# 3068935

# %%
int(df[df['season']=='Fall']['Profit'].sum())
# Out:
# 5243300

# %% [markdown]
# """""
# task 1 finished
# """""""

# %%
df.to_csv('bikes2.csv')

# %%
d=pd.read_csv('loan_data.csv')

# %%
d
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
d.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
d['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
d['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
d[d['Gender']=='Male']['Loan_Status'].value_counts()
# Out:
# Y    339
# N    150
# Name: Loan_Status, dtype: int64

# %%
d[d['Gender']=='Female']['Loan_Status'].value_counts()
# Out:
# Y    75
# N    37
# Name: Loan_Status, dtype: int64

# %%
d.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
d[d['Married']=='Yes']['Loan_Status'].value_counts()
# Out:
# Y    285
# N    113
# Name: Loan_Status, dtype: int64

# %%
d.groupby('LoanAmount').sum()['Loan_Amount_Term'].head(1)
# Out:
# LoanAmount
# 9.0    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
d.groupby('ApplicantIncome').sum()
# Out:
#                  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ApplicantIncome
# 150                         1800.0       135.0             360.0
# 210                         2917.0        98.0             360.0
# 416                        41667.0       350.0             180.0
# 645                         3683.0       113.0             480.0
# 674                         5296.0       168.0             360.0
# ...                            ...         ...               ...
# 39147                       4750.0       120.0             360.0
# 39999                          0.0       600.0             180.0
# 51763                          0.0       700.0             300.0
# 63337                          0.0       490.0             180.0
# 81000                          0.0       360.0             360.0
#
#                  Credit_History
# ApplicantIncome
# 150                         1.0
# 210                         1.0
# 416                         0.0
# ...

# %%
d[d['Self_Employed']=='Yes']['Loan_Status'].value_counts()
# Out:
# Y    56
# N    26
# Name: Loan_Status, dtype: int64

# %%
d[d['Self_Employed']=='No']['Loan_Status'].value_counts()
# Out:
# Y    343
# N    157
# Name: Loan_Status, dtype: int64

# %%
d[d['Education']=='Graduate']['Loan_Status'].value_counts()
# Out:
# Y    340
# N    140
# Name: Loan_Status, dtype: int64

# %%
d[d['Education']=='Not Graduate']['Loan_Status'].value_counts()
# Out:
# Y    82
# N    52
# Name: Loan_Status, dtype: int64
