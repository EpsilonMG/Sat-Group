# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bikes.csv')
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
### Make Profit Feature.

def calculate_profit(x):
    casual_customers =x['casual']
    registerd_customers =x['registered']
    registerd_price_per_hour = 5
    casual_price_per_hour = 20
    taxes= 0.14 
    maintance_per_year=1500/(12*30*24)
    profit_=taxes*(casual_customers*(casual_price_per_hour+maintance_per_year)+registerd_customers*(casual_price_per_hour+maintance_per_year))
    return profit_
df['profit'] = df[['casual', 'registered']].apply(calculate_profit, axis=1)  
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count  \
# ...

# %%
### Distribution rental_bikes_count & profit.
df['profit'].describe()
# Out:
# count    10886.000000
# mean       541.063885
# std        511.607287
# min          2.824306
# 25%        118.620833
# 50%        409.524306
# 75%        802.102778
# max       2759.346528
# Name: profit, dtype: float64

# %%
plt.hist(df['profit'])
plt.show()

# %%
df['rented_bikes_count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: rented_bikes_count, dtype: float64

# %%
plt.hist(df['rented_bikes_count'])
plt.show()

# %%
### Profit for each day.
df['day']=df['datetime'].apply( lambda x : x.split()[0])
df.groupby('day').sum()['profit']
# Out:
# day
# 2011-01-01     2781.940972
# 2011-01-02     2262.268750
# 2011-01-03     3809.988194
# 2011-01-04     4411.565278
# 2011-01-05     4518.888889
#                   ...
# 2012-12-15    14254.270139
# 2012-12-16    10692.820833
# 2012-12-17    12949.440972
# 2012-12-18    15694.665972
# 2012-12-19    14875.617361
# Name: profit, Length: 456, dtype: float64

# %%
### Which season that has more registeration & profit.
df.groupby('season').sum()['profit']
# Out:
# season
# Fall      1.774748e+06
# Spring    8.636133e+05
# Summer    1.619118e+06
# Winter    1.508267e+06
# Name: profit, dtype: float64

# %%
df.groupby('season').sum()['registered']
# Out:
# season
# Fall      488252
# Spring    265322
# Summer    446991
# Winter    457276
# Name: registered, dtype: int64

# %%
### Which weather condition that has more registeration & profit.
df.groupby('weather').sum()['registered']
# Out:
# weather
# Clear    951449
# Mist     336229
# Rainy     70204
# Snowy       158
# Name: registered, dtype: int64

# %%
df.groupby('weather').sum()['profit']
# Out:
# weather
# Clear    3.339476e+06
# Mist     1.146645e+06
# Rainy    2.324065e+05
# Snowy    4.631861e+02
# Name: profit, dtype: float64

# %%
### Correlation between profit & bikes count with all features.

df[['profit','rented_bikes_count']].corr()
# Out:
#                     profit  rented_bikes_count
# profit                 1.0                 1.0
# rented_bikes_count     1.0                 1.0

# %%
### Rentals during rush hours (7-9 am & 3-5 pm).
df['Rentals_HOURS']=df['datetime'].apply(lambda x : int(x.split()[1][0:2]))
df[(df['Rentals_HOURS'].between(7,9,inclusive=True)) | (df['Rentals_HOURS'].between(15,17,inclusive=True))].groupby('Rentals_HOURS').sum()['rented_bikes_count']
# Out:
# Rentals_HOURS
# 7      96968
# 8     165060
# 9     100910
# 15    115960
# 16    144266
# 17    213757
# Name: rented_bikes_count, dtype: int64

# %%
###  Registered or casual is more.
df[['casual','registered']].sum()
# Out:
# casual         392135
# registered    1693341
# dtype: int64

# %%
### Rentals during workday & holiday.
df['rented_bikes_count'][(df['workingday']==1) | (df['holiday']==1)]
# Out:
# 47         5
# 48         2
# 50         3
# 51        30
# 52        64
#         ...
# 10881    336
# 10882    241
# 10883    168
# 10884    129
# 10885     88
# Name: rented_bikes_count, Length: 6659, dtype: int64

# %%
df['formatted_date']= pd.to_datetime(df['datetime'])
df['week_of_year'] = df.formatted_date.apply(lambda x: x.weekofyear)
df.groupby('week_of_year').mean()['rented_bikes_count'].mean()
# Out:
# 190.29099156657995

# %%
def _day (x):
    if '-12-09' in x :
        return True
    elif '-06-02' in x:
        return True
    else : 
        return False
df[df['day'].apply(_day)].groupby('day').sum()['profit']
# Out:
# day
# 2011-06-02    14031.150000
# 2011-12-09    10223.986111
# 2012-06-02    22933.361111
# 2012-12-09     9116.858333
# Name: profit, dtype: float64

# %%
sum(df['profit'].loc[0:24*356]) + sum(df['profit'][df['season']=='Fall']) + sum(df['profit'].loc[24*356::24*7])
# Out:
# 5943330.220138915

# %% [markdown]
# ### Task 2

# %%
datf=pd.read_csv('loan_data.csv')
datf
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
datf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
datf.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
datf[datf['Gender']=='Male']['ApplicantIncome'].mean(),datf[datf['Gender']=='Female']['ApplicantIncome'].mean(),
# Out:
# (5446.460122699386, 4643.473214285715)

# %%
datf['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
datf['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
datf['ApplicantIncome'].sum()
# Out:
# 3317724

# %%
datf['Dependents'] >= '1'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610     True
# 611     True
# 612     True
# 613    False
# Name: Dependents, Length: 614, dtype: bool

# %%
datf[datf['Education']=='Graduate'][datf['Self_Employed']=='Yes']
# Out:
# <ipython-input-91-af37b38ca3eb>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf[datf['Education']=='Graduate'][datf['Self_Employed']=='Yes']
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 25   LP001066    Male     Yes          0  Graduate           Yes
# 32   LP001097    Male      No          1  Graduate           Yes
# 54   LP001186  Female     Yes          1  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 591  LP002931    Male     Yes          2  Graduate           Yes
# 592  LP002933     NaN      No         3+  Graduate           Yes
# 594  LP002938    Male     Yes          0  Graduate           Yes
# 598  LP002945    Male     Yes          0  Graduate           Yes
# 613  LP002990  Female      No          0  Graduate           Yes
#
# ...

# %%
datf[datf['Married']=='Yes'][datf['Self_Employed']=='Yes'][datf['ApplicantIncome'] > 1000]
# Out:
# <ipython-input-98-e4e391557d3d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf[datf['Married']=='Yes'][datf['Self_Employed']=='Yes'][datf['ApplicantIncome'] > 1000]
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 62   LP001207    Male     Yes          0  Not Graduate           Yes
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 71   LP001245    Male     Yes          2  Not Graduate           Yes
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# ...

# %%
datf[datf['Married']=='Yes'][datf['ApplicantIncome'] > 1000].mean()
# Out:
# <ipython-input-104-282477b6f394>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf[datf['Married']=='Yes'][datf['ApplicantIncome'] > 1000].mean()
# ApplicantIncome      5681.159898
# CoapplicantIncome    1779.768832
# LoanAmount            156.044737
# Loan_Amount_Term      336.748052
# Credit_History          0.840782
# dtype: float64

# %%
datf[(datf['Gender']=='Male')& ((datf['Dependents'] =='2')|(datf['Dependents'] =='+3'))]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 8    LP001018   Male     Yes          2      Graduate            No
# 10   LP001024   Male     Yes          2      Graduate            No
# 11   LP001027   Male     Yes          2      Graduate           NaN
# 12   LP001028   Male     Yes          2      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 591  LP002931   Male     Yes          2      Graduate           Yes
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 599  LP002948   Male     Yes          2      Graduate            No
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5               5417             4196.0       267.0             360.0
# ...

# %%
datf[datf['Married']=='No'][datf['Self_Employed']=='Yes'][datf['ApplicantIncome'] > 1000][datf['Dependents'] == '1']
# Out:
# <ipython-input-111-efd52a06fc1f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf[datf['Married']=='No'][datf['Self_Employed']=='Yes'][datf['ApplicantIncome'] > 1000][datf['Dependents'] == '1']
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0       106.0             360.0
# 113             7451                0.0         NaN             360.0
# ...

# %%
datf[datf['Married']=='No'][datf['Education']=='Graduate'][datf['ApplicantIncome'] > 500][datf['Dependents'] == '1']
# Out:
# <ipython-input-116-b3505f06bd8c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf[datf['Married']=='No'][datf['Education']=='Graduate'][datf['ApplicantIncome'] > 500][datf['Dependents'] == '1']
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 32   LP001097    Male      No          1  Graduate           Yes
# 113  LP001392  Female      No          1  Graduate           Yes
# 238  LP001790  Female      No          1  Graduate            No
# 262  LP001870  Female      No          1  Graduate            No
# 269  LP001884  Female      No          1  Graduate            No
# 318  LP002043  Female      No          1  Graduate            No
# 330  LP002097    Male      No          1  Graduate            No
# 360  LP002161  Female      No          1  Graduate            No
# 373  LP002205    Male      No          1  Graduate            No
# 385  LP002237    Male      No          1  Graduate           NaN
# ...
